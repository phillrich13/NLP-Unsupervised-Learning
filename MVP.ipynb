# %% [markdown]
# # MVP

# %% [markdown]
# I have downloaded ~122,000 tweets containing the official hashtag of the E3 conference (#E32021) using tweepy. These tweets were pulled on 6/15 between. 8p.m. and midnight (this matters because Nintendo's conference was on 6/15 so there will be less tweets for Nintendo compared to companies that went earlier). My first step was to pre-process the tweets. This included removing hyperlinks, '...', lowercase, splitting specific hashtags (each company had a specific hashtag for their presentation), removing stop words, removing punctuation, and more. I then fit 2 vectorizers for testing (TF-IDF and CountVectorizer), as well as 2 topic modelers (NMF, LSA) and then tested multiple iterations of the vectorizers and topic models. My best topic modeler (NMF with 7 topics and TF-IDF vectorizer) produced the following topics:
#
# ### Topic 0: (XBOX)
#
#  XBOX, BETHESDA, 20, SHOWCASE, STARFIELD, GAMEPASS, MICROSOFT, PASS, FORZA, EXCLUSIVE, GO, XBOXSERIESX, SHOW, FRIDGE, REDFALL, READY, HORIZON, COMING, LET, SERIES, HADES, MINI, OUTER, WORLDS, BEST, XBOXE3, LIVE, BATTLEFIELD2042, STALKER, LETS
#
# ### Topic 1: (Nintendo Post-Conference)
#
#  NINTENDO, DIRECT, METROID, DREAD, BOTW2, ZELDA, NINTENDOSWITCH, BREATH, WILD, GO, SWITCH, SMASH, WARS, ADVANCE, MARIO, WARIOWARE, BOTW, SMASHBROSULTIMATE, WARIO, DIRECTE3, NEW, BREATHOFTHEWILD2, LET, KAZUYA, LIFE, BALL, PARTY, LIVE, STRANGE, FATAL
#
# ### Topic 2: (Square Enix)
#
#  SQUARE, ENIX, PRESENTS, GUARDIANS, GALAXY, FINAL, FANTASY, MARVEL, PRESENTATION, TIME, AVENGERS, SHOWCASE, LIVE, GO, LIFE, LET, STRANGE, CHAOS, MOBILE, SHOW, ORIGIN, NEXT, LIFEISSTRANGE, STRANGER, PARADISE, BABYLON, FALL, MINUTES, GOTG, FF
#
# ### Topic 3: (Nintendo Pre-Conference)
#
#  NINTENDO, DIRECT, ANNOUNCED, DAYS, SWITCH, SAVE, TOMORROW, TODAY, WINS, SAVED, LIVE, METROID, 15, PLEASE, TREEHOUSE, US, REVEALED, YEAR, PRESENTATION, MARIO, ZELDA, NINTENDOSWITCH, DAY, LET, HOPE, 10, THANK, BOTW2, PREDICTIONS, DREAD
#
# ### Topic 4: (Ubisoft)
#
#  FORWARD, UBISOFT, UBI, LOOKING, AVATAR, LIVE, MARIO, RABBIDS, FARCRY6, RAINBOW, R6EXTRACTION, FAR, ROCKSMITH, LOOK, SIX, MARIORABBIDS, SHOW, RIDERSREPUBLIC, EXTRACTION, CRY, WATCHING, PRESENTATION, SUMMERGAMEFEST, WATCH, GEARBOX, DANCE, SPARKS, EVENT, HOPE, MINUTES
#
# ### Topic 5: (E3 General)
#
#  HALO, LOOKS, GAMES, INFINITE, NEW, TODAY, DAY, SEE, IT, WAIT, EXCITED, CAN, TIME, ONE, YEAR, REALLY, SHOW, GET, METROID, PLAY, GO, GREAT, FAR, GUARDIANS, COMING, LET, TRAILER, GALAXY, VIDEO, COOL
#
# ### Topic 6: (Capcom)
#
#  CAPCOM, SHOWCASE, TIME, PRESENTATION, LIVE, SHOW, WATCHING, THAT, WATCH, ACE, ATTORNEY, DLC, RESIDENT, VILLAGE, NOTHING, TODAY, MONSTER, EVIL, REALLY, HUNTER, PLEASE, WORST, US, LET, TAKE, WELL, MINUTES, GEARBOX, COME, RESIDENTEVILVILLAGE
#
#
# The topics ended up being clear after landing on my final combination of NMF/TF-IDF. My next step after producing the models was to create wordclouds for each of the topics. I ended up excluding the general group because I am focused on competitive intelligence, and the general group doesn't give good information on main competitors of playstation.

# %% [markdown]
# ## Xbox Wordcloud

# %% [markdown]
# ![xbox e3.png](attachment:89339488-1cf0-4607-a331-26836b5c1581.png)

# %% [markdown]
# ## Nintendo (pre-conference) Wordcloud

# %% [markdown]
# ![nintendo pre e3.png](attachment:0abccaa1-41f1-4ec1-a370-19fe27072b58.png)

# %% [markdown]
# ## Nintendo (post-conference) Wordcloud

# %% [markdown]
# ![nintendo post e3.png](attachment:b46fc65e-305b-4104-ae84-528d37deeb83.png)

# %% [markdown]
# ## Square Enix Wordcloud

# %% [markdown]
# ![se e3.png](attachment:cd373e4b-533a-478a-90a7-ad3cfd06a5bd.png)

# %% [markdown]
# ## Ubisoft Wordcloud

# %% [markdown]
# ![ubisoft e3.png](attachment:d9edd509-bca9-4f31-b825-638095abe100.png)

# %% [markdown]
# ## Capcom Wordcloud

# %% [markdown]
# ![capcom e3.png](attachment:5078b5d8-9b4c-43e6-bd57-a14e931a2119.png)
