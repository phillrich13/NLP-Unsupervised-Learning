# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
import numpy as np
import os
import matplotlib.pyplot as plt
from PIL import Image

# %%
topics = pd.read_pickle(r'/Users/philliprichardson/Metis/Module 5/topics.pkl')

# %% [markdown]
# ## Create Topic specific DataFrames

# %%
gen_e3 = topics[(topics.topic == 'General E3')]
xbox = topics[(topics.topic == 'Xbox')]
SE = topics[(topics.topic == 'Square Enix')]
nin_post = topics[(topics.topic == 'Nintendo (post-presentation)')]
ubi = topics[(topics.topic == 'Ubisoft')]
nin_pre = topics[(topics.topic == 'Nintendo (pre-presentation)')]
capcom = topics[(topics.topic == 'Capcom')]

# %% [markdown]
# ## Creating a stopwords list and constantly updating to ensure clean word cloud. many uninformative words included

# %%
stopwords = nltk.corpus.stopwords.words('english')

# Since all tweets are about E3, no real meaning with keeping these words.
updated_stopwords = ['e', 'e3', 'e32021', ' 2021', '2021 ','2021','2022', 'like', 'good', 'game', 'nintendoe3', 'of', 'fucking', 'conference', 'present', 'shit', 'presentation', 'showcase', 'presents', 'presentssquare', 
                     'presentation', 'present', 'showcase', 'presents', 'announcement', 'announced', 'show', 'look', 'looking', '.', 'DirectNintendo', 'capcomcapcom', 'looks', 'forwardubisoft', 'forwardubi', 'enixsquare', 
                     'xboxxbox']
stopwords.extend(updated_stopwords)

# %% [markdown]
# # Xbox Wordcloud

# %%
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
# mask = np.array(Image.open(os.path.join(d, r'/Users/philliprichardson/Metis/Module 5/images/xbox.jpeg')))

wordcloud = WordCloud(collocations = False, stopwords = stopwords_x).generate(''.join(xbox.Tweet))



wordcloud.recolor( colormap = 'Greens')
# Display the generated image:
plt.figure(figsize = (12,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
plt.savefig("/Users/philliprichardson/Metis/Module 5/xbox e3",bbox_inches='tight')

# %% [markdown]
# # Capcom Wordcloud

# %%
wordcloud = WordCloud(collocations = False, stopwords = stopwords_x).generate(''.join(capcom.Tweet))

wordcloud.recolor(random_state = 37, colormap = 'YlGnBu')
# Display the generated image:
plt.figure(figsize = (12,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
plt.savefig("/Users/philliprichardson/Metis/Module 5/capcom e3",bbox_inches='tight')

# %% [markdown]
# # Square Enix Wordcloud

# %%
wordcloud = WordCloud(collocations = False, stopwords = stopwords_x).generate(''.join(SE.Tweet))

wordcloud.recolor(colormap = 'RdGy')
# Display the generated image:
plt.figure(figsize = (12,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
plt.savefig("/Users/philliprichardson/Metis/Module 5/se e3",bbox_inches='tight')

# %% [markdown]
# # Nintendo Post Conference Wordcloud

# %%
wordcloud = WordCloud(collocations = False, stopwords = stopwords_x).generate(''.join(nin_post.Tweet))

wordcloud.recolor(colormap = 'Reds')
# Display the generated image:
plt.figure(figsize = (12,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
plt.savefig("/Users/philliprichardson/Metis/Module 5/nintendo post e3",bbox_inches='tight')

# %% [markdown]
# # Ubisoft Wordcloud

# %%
wordcloud = WordCloud(collocations = False, stopwords = stopwords_x).generate(''.join(ubi.Tweet))

wordcloud.recolor(random_state = 13, colormap = 'gist_yarg')
# Display the generated image:
plt.figure(figsize = (12,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
plt.savefig("/Users/philliprichardson/Metis/Module 5/ubisoft e3",bbox_inches='tight')

# %% [markdown]
# # Nintendo Pre Conference Word Cloud

# %%
wordcloud = WordCloud(collocations = False, stopwords = stopwords_x).generate(''.join(nin_pre.Tweet))

wordcloud.recolor(random_state = 13, colormap = 'Reds')
# Display the generated image:
plt.figure(figsize = (12,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");
plt.savefig("/Users/philliprichardson/Metis/Module 5/nintendo pre e3",bbox_inches='tight')

# %% [markdown]
# ## Exporting Sentiment for Tableau visualization

# %%
topics2 = topics[['Tweet', 'topic', 'sentiment', 'sentiment_tert']]

topics3 = topics2[(topics2.topic != 'General E3')]

topics3.to_csv(r'/Users/philliprichardson/Metis/Module 5/sentiment.csv')
